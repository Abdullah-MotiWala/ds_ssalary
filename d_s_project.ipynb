# %%
import glassdoor_scrapper as gs
import pandas as pd

# %%
path = "D:/codee/ds_salary_project/chromedriver"
gs.get_jobs('data scientist',15,True,path,15)
# Out:
#  x worked out
# Progress: 0/15
# Job Title: Data Scientist
# Salary Estimate: $123,938 /yr (est.)
# Rating: 4.8
# Company Name: Retool
# 4.8
# Location: San Francisco, CA
# Size: 51 to 200 Employees
# Founded: 2017
# Type of Ownership: Company - Private
# Industry: Computer Hardware Development
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress: 1/15
# Job Title: Data Scientist
# Salary Estimate: $151,378 /yr (est.)
# Rating: 3.3
# Company Name: Wish
# 3.3
# Location: San Francisco, CA
# Size: 1001 to 5000 Employees
# Founded: 2010
# Type of Ownership: Company - Public
# Industry: Internet & Web Services
# Sector: Information Technology
# Revenue: $1 to $5 billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress: 2/15
# Job Title: Data Scientist
# Salary Estimate: $130,565 /yr (est.)
# Rating: 3.7
# Company Name: Mercury
# 3.7
# Location: San Francisco, CA
# ...
